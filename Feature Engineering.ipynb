# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#              id  acc_data_vintage  amazonpay_recency  amt_cash_wdl_c30  \
# 0  6.550540e+15              55.0                NaN               NaN
# 1  6.550770e+15              34.0                NaN               NaN
# 2  6.550830e+15               8.0                NaN               NaN
# 3  6.550880e+15              28.0                NaN               NaN
# 4  6.550890e+15               NaN                NaN               NaN
#
#    amt_cash_wdl_c7  amt_cash_wdl_m0  amt_cash_wdl_m1  amt_cash_wdl_m2  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN          60000.0              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    amt_cash_wdl_m3  amt_cash_wdl_p30  ...  internet_acc0_av_balance_c60  \
# ...

# %%
df.describe()
# Out:
#                  id  acc_data_vintage  amazonpay_recency  amt_cash_wdl_c30  \
# count  1.609600e+04      13789.000000         199.000000      5.879000e+03
# mean   6.917172e+15        163.332874          32.768844      1.592589e+04
# std    1.771371e+14        249.662269          37.979352      3.889183e+04
# min    6.550510e+15          0.000000           0.000000      8.000000e+00
# 25%    6.778798e+15         41.000000           6.000000      2.300000e+03
# 50%    6.954710e+15        108.000000          18.000000      7.100000e+03
# 75%    7.069720e+15        220.000000          47.000000      1.670000e+04
# max    8.089780e+15      17685.000000         176.000000      1.107000e+06
#
#        amt_cash_wdl_c7  amt_cash_wdl_m0  amt_cash_wdl_m1  amt_cash_wdl_m2  \
# count      3437.000000     4.226000e+03      4999.000000      3660.000000
# mean       9416.999165     1.195172e+04     14641.249010     14323.591227
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Columns: 1062 entries, id to target
# dtypes: bool(3), float64(1047), int64(7), object(5)
# memory usage: 130.1+ MB

# %%
df.isnull().sum()
# Out:
# id                              0
# acc_data_vintage             2307
# amazonpay_recency           15897
# amt_cash_wdl_c30            10217
# amt_cash_wdl_c7             12659
#                             ...
# consumer_businesses_perc     3610
# bank_perc                    3610
# financial_services_perc      3610
# nbfc_digital_lender_perc     3610
# target                          0
# Length: 1062, dtype: int64

# %%
df_bool=df.select_dtypes(include='bool')
df_bool.isnull().sum()
# Out:
# temp_net_banking_flag        0
# temp_is_businessman          0
# temp_debit_card_user_flag    0
# dtype: int64

# %%
df_float=df.select_dtypes(include='float64')
df_float.isnull().sum()
# Out:
# id                              0
# acc_data_vintage             2307
# amazonpay_recency           15897
# amt_cash_wdl_c30            10217
# amt_cash_wdl_c7             12659
#                             ...
# government_service_perc      3610
# consumer_businesses_perc     3610
# bank_perc                    3610
# financial_services_perc      3610
# nbfc_digital_lender_perc     3610
# Length: 1047, dtype: int64

# %%
df_int=df.select_dtypes(include='int64')
df_int.isnull().sum()
# Out:
# cnt_active_accounts_c90         0
# cnt_ewallets_used               0
# cnt_savings_accounts            0
# cnt_unique_wallets_used         0
# temp_cnt_savings_accounts       0
# temp_cnt_active_accounts_c90    0
# target                          0
# dtype: int64

# %%
df_categorical=df.select_dtypes(include='object')
df_categorical.isnull().sum()
# Out:
# secondary_acc_bank             8547
# temp_secondary_acc_bank        8316
# temp_primary_acc_bank          2600
# temp_primary_acc_acc_number    2600
# primary_acc_bank               2695
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
#              id  acc_data_vintage  amazonpay_recency  amt_cash_wdl_c30  \
# 0  6.550540e+15         55.000000          32.768844      15925.888323
# 1  6.550770e+15         34.000000          32.768844      15925.888323
# 2  6.550830e+15          8.000000          32.768844      15925.888323
# 3  6.550880e+15         28.000000          32.768844      15925.888323
# 4  6.550890e+15        163.332874          32.768844      15925.888323
#
#    amt_cash_wdl_c7  amt_cash_wdl_m0  amt_cash_wdl_m1  amt_cash_wdl_m2  \
# 0      9416.999165     11951.718443      14641.24901     14323.591227
# 1      9416.999165     11951.718443      60000.00000     14323.591227
# 2      9416.999165     11951.718443      14641.24901     14323.591227
# 3      9416.999165     11951.718443      14641.24901     14323.591227
# 4      9416.999165     11951.718443      14641.24901     14323.591227
#
#    amt_cash_wdl_m3  amt_cash_wdl_p30  ...  internet_acc0_av_balance_c60  \
# ...

# %%
df_categorical
# Out:
#       secondary_acc_bank temp_secondary_acc_bank  \
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
# ...                  ...                     ...
# 16091              kotak                   kotak
# 16092            yesbank                     pnb
# 16093                NaN                     NaN
# 16094                sbi                     sbi
# 16095              kotak                   kotak
#
#                          temp_primary_acc_bank  \
# 0                               syndicate bank
# 1                                        icici
# 2                               bank of baroda
# 3                                         hdfc
# 4                                          NaN
# ...                                        ...
# ...

# %%
df['secondary_acc_bank'].fillna(df['secondary_acc_bank'].mode()[0], inplace=True)
df['temp_secondary_acc_bank'].fillna(df['temp_secondary_acc_bank'].mode()[0], inplace=True)
df['temp_primary_acc_bank'].fillna(df['temp_primary_acc_bank'].mode()[0], inplace=True)
df['temp_primary_acc_acc_number'].fillna(df['temp_primary_acc_acc_number'].mode()[0], inplace=True)
df['primary_acc_bank'].fillna(df['primary_acc_bank'].mode()[0], inplace=True)

# %%
df
# Out:
#                  id  acc_data_vintage  amazonpay_recency  amt_cash_wdl_c30  \
# 0      6.550540e+15         55.000000          32.768844      15925.888323
# 1      6.550770e+15         34.000000          32.768844      15925.888323
# 2      6.550830e+15          8.000000          32.768844      15925.888323
# 3      6.550880e+15         28.000000          32.768844      15925.888323
# 4      6.550890e+15        163.332874          32.768844      15925.888323
# ...             ...               ...                ...               ...
# 16091  7.766730e+15        138.000000          32.768844      15925.888323
# 16092  7.772870e+15        354.000000          32.768844      15925.888323
# 16093  7.874680e+15        413.000000          32.768844      15925.888323
# 16094  8.053890e+15         72.000000          32.768844      15925.888323
# 16095  8.083550e+15         25.000000          32.768844      15925.888323
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.to_csv('new_data.csv')
